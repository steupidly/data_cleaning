# %%
'''import moduls'''
import pandas as pd
import json
import ast
import numpy as np

# %%
''' import dataset and get some informations'''
df = pd.read_csv('movies_metadata.csv', low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
df.genres#[0]
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
'''drop irrelevant columns
adult, imdb_id, original_title, video, homepage'''
df.drop(columns=['adult','imdb_id','original_title','video','homepage'], inplace= True)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45461                fa        Rising and falling between a man and woman.
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                       poster_path  \
# 0      21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2        11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3       3.859495  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4       8.387519  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...          ...                               ...
# 45461   0.072051  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462   0.178241  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463   0.903007  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464   0.003503  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465   0.163015  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45466 rows x 19 columns]

# %% [markdown]
# How to handle Json columns

# %%
# beberapa column yang tipe data json
json_col = ['belongs_to_collection','genres','production_companies','production_countries','spoken_languages']

# %%
df.belongs_to_collection[0]
# Out:
# "{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}"

# %%
json1 = "{'dog':3 ,'cat':5}"

# %%
json2 ='{"dog":3,"cat":5}'

# %%
json.loads(json2)
# Out:
# {'dog': 3, 'cat': 5}

# %%
json1.replace("'",'"')
# Out:
# '{"dog":3 ,"cat":5}'

# %%
json.loads(json1.replace("'",'"'))
# Out:
# {'dog': 3, 'cat': 5}

# %%
df.genres.apply(lambda x :json.loads(x.replace("'",'"')))#[0]
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
df.genres
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
ast.literal_eval(json1)
# Out:
# {'dog': 3, 'cat': 5}

# %%
ast.literal_eval(json2)
# Out:
# {'dog': 3, 'cat': 5}

# %%
df.genres.apply(ast.literal_eval)
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
df.genres = df.genres.apply(ast.literal_eval)

# %%
df.loc[:,json_col]
# Out:
#                                    belongs_to_collection  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                    NaN
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                    NaN
# 4      {'id': 96871, 'name': 'Father of the Bride Col...
# ...                                                  ...
# 45461                                                NaN
# 45462                                                NaN
# 45463                                                NaN
# 45464                                                NaN
# 45465                                                NaN
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                  ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#
#                                         spoken_languages
# 0               [{'iso_639_1': 'en', 'name': 'English'}]
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2               [{'iso_639_1': 'en', 'name': 'English'}]
# 3               [{'iso_639_1': 'en', 'name': 'English'}]
# 4               [{'iso_639_1': 'en', 'name': 'English'}]
# ...                                                  ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                 []
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]
#
# [45466 rows x 5 columns]

# %% [markdown]
# Handle Json Columns

# %%
df.belongs_to_collection.apply(lambda x : isinstance(x,str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df.belongs_to_collection=df.belongs_to_collection.apply(lambda x : ast.literal_eval(x)if isinstance(x,str) else np.nan)

# %%
df.belongs_to_collection
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.spoken_languages=df.spoken_languages.apply(lambda x : ast.literal_eval(x)if isinstance(x,str) else np.nan)

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.production_countries=df.production_countries.apply(lambda x : ast.literal_eval(x)if isinstance(x,str) else np.nan)

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_companies=df.production_companies.apply(lambda x : ast.literal_eval(x)if isinstance(x,str) else np.nan)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464                                                 []  227506
# 45465                                                 []  461257
#
#       original_language                                           overview  \
# 0                    en  Led by Woody, Andy's toys live happily in his ...
# 1                    en  When siblings Judy and Peter discover an encha...
# 2                    en  A family wedding reignites the ancient feud be...
# 3                    en  Cheated on, mistreated and stepped on, the wom...
# 4                    en  Just when George Banks has recovered from his ...
# ...                 ...                                                ...
# 45461                fa        Rising and falling between a man and woman.
# 45462                tl  An artist struggles to finish his work while a...
# 45463                en  When one of her hits goes wrong, a professiona...
# 45464                en  In a small town live two brothers, one a minis...
# 45465                en  50 years after decriminalisation of homosexual...
#
#       popularity                       poster_path  \
# 0      21.946943  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      17.015539  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2        11.7129  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3       3.859495  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4       8.387519  /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...          ...                               ...
# 45461   0.072051  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462   0.178241  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463   0.903007  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464   0.003503  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465   0.163015  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#            revenue  runtime  \
# 0      373554033.0     81.0
# 1      262797249.0    104.0
# 2              0.0    101.0
# 3       81452156.0    127.0
# 4       76578911.0    106.0
# ...            ...      ...
# 45461          0.0     90.0
# 45462          0.0    360.0
# 45463          0.0     90.0
# 45464          0.0     87.0
# 45465          0.0     75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45466 rows x 19 columns]

# %%
df.belongs_to_collection
# Out:
# 0        {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                                      NaN
# 2        {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                      NaN
# 4        {'id': 96871, 'name': 'Father of the Bride Col...
#                                ...
# 45461                                                  NaN
# 45462                                                  NaN
# 45463                                                  NaN
# 45464                                                  NaN
# 45465                                                  NaN
# Name: belongs_to_collection, Length: 45466, dtype: object

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x : x['name'] if isinstance(x,dict)else np.nan)

# %%
df.belongs_to_collection[0]
# Out:
# 'Toy Story Collection'

# %%
df.genres[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df.genres = df.genres.apply(lambda x: '|'.join(i['name']for i in x))

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
df.genres.value_counts(dropna=False).head(20)
# Out:
# Drama                   5000
# Comedy                  3621
# Documentary             2723
#                         2442
# Drama|Romance           1301
# Comedy|Drama            1135
# Horror                   974
# Comedy|Romance           930
# Comedy|Drama|Romance     593
# Drama|Comedy             532
# Horror|Thriller          528
# Drama|Thriller           497
# Thriller                 465
# Crime|Drama              430
# Romance|Drama            343
# Western                  318
# Action|Thriller          301
# Drama|Foreign            283
# Action                   278
# Drama|History            267
# Name: genres, dtype: int64

# %%
df.genres.replace("",np.nan, inplace=True)

# %%
df.genres
# Out:
# 0         Animation|Comedy|Family
# 1        Adventure|Fantasy|Family
# 2                  Romance|Comedy
# 3            Comedy|Drama|Romance
# 4                          Comedy
#                    ...
# 45461                Drama|Family
# 45462                       Drama
# 45463       Action|Drama|Thriller
# 45464                         NaN
# 45465                         NaN
# Name: genres, Length: 45466, dtype: object

# %%
df.spoken_languages=df.spoken_languages.apply(lambda x: '|'.join(i['name']for i in x) if isinstance (x,list) else np.nan)

# %%
df.spoken_languages.value_counts(dropna=False)
# Out:
# English                           22395
#                                    3952
# Français                           1853
# 日本語                                1289
# Italiano                           1218
#                                   ...
# English|日本語|Latin                     1
# Deutsch||ελληνικά|English             1
# English|suomi|Deutsch|svenska         1
# English|Français|Deutsch|فارسی        1
# Fulfulde|English                      1
# Name: spoken_languages, Length: 1843, dtype: int64

# %%
df.spoken_languages.replace("", np.nan,inplace=True)

# %%
df.spoken_languages.value_counts(dropna=False)
# Out:
# English                           22395
# NaN                                3958
# Français                           1853
# 日本語                                1289
# Italiano                           1218
#                                   ...
# Deutsch||ελληνικά|English             1
# English|suomi|Deutsch|svenska         1
# English|Français|Deutsch|فارسی        1
# svenska|English|Español               1
# Fulfulde|English                      1
# Name: spoken_languages, Length: 1842, dtype: int64

# %%
df.production_countries
# Out:
# 0        [{'iso_3166_1': 'US', 'name': 'United States o...
# 1        [{'iso_3166_1': 'US', 'name': 'United States o...
# 2        [{'iso_3166_1': 'US', 'name': 'United States o...
# 3        [{'iso_3166_1': 'US', 'name': 'United States o...
# 4        [{'iso_3166_1': 'US', 'name': 'United States o...
#                                ...
# 45461               [{'iso_3166_1': 'IR', 'name': 'Iran'}]
# 45462        [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45463    [{'iso_3166_1': 'US', 'name': 'United States o...
# 45464             [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45465     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
# Name: production_countries, Length: 45466, dtype: object

# %%
df.production_countries=df.production_countries.apply(lambda x: '|'.join(i['name']for i in x) if isinstance (x,list) else np.nan)

# %%
df.production_countries.value_counts(dropna=False)
# Out:
# United States of America                  17851
#                                            6282
# United Kingdom                             2238
# France                                     1654
# Japan                                      1356
#                                           ...
# Romania|United Kingdom|Canada                 1
# Finland|Germany|Netherlands                   1
# France|Denmark|Spain|Sweden                   1
# France|United States of America|Canada        1
# Egypt|Italy|United States of America          1
# Name: production_countries, Length: 2391, dtype: int64

# %%
df.production_countries.replace("",np.nan,inplace=True)

# %%
df.production_countries.value_counts(dropna=False)
# Out:
# United States of America                  17851
# NaN                                        6288
# United Kingdom                             2238
# France                                     1654
# Japan                                      1356
#                                           ...
# Romania|United Kingdom|Canada                 1
# Finland|Germany|Netherlands                   1
# France|Denmark|Spain|Sweden                   1
# France|United States of America|Canada        1
# Egypt|Italy|United States of America          1
# Name: production_countries, Length: 2390, dtype: int64

# %%
df.production_companies = df.production_companies.apply(lambda x: '|'.join(i['name']for i in x) if isinstance (x,list) else np.nan)

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 45461
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465
# Name: production_companies, Length: 45466, dtype: object

# %%
df.production_companies.value_counts(dropna=False)
# Out:
#                                                                                                                                               11875
# Metro-Goldwyn-Mayer (MGM)                                                                                                                       742
# Warner Bros.                                                                                                                                    540
# Paramount Pictures                                                                                                                              505
# Twentieth Century Fox Film Corporation                                                                                                          439
#                                                                                                                                               ...
# HBO Films|Moving Pictures                                                                                                                         1
# BIM Distribuzione|Canal+|Alta Producción|Centre National de la Cinématographie (CNC)|Rézo Productions|Compagnie Eric Rohmer (CER)|Cinémage        1
# Galatée Films|Novo Arturo Films|Constantin Film Produktion|Pathé|France 2 Cinéma|France 3 Cinema|Logline Studios|Blue Screen Productions          1
# Fox Searchlight Pictures|26 Films                                                                                                                 1
# Yermoliev                                                                                                                                         1
# Name: production_companies, Length: 22673, dtype: int64

# %%
df.production_companies.replace("", np.nan, inplace=True)

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 45461                                                  NaN
# 45462                                          Sine Olivia
# 45463                              American World Pictures
# 45464                                            Yermoliev
# 45465                                                  NaN
# Name: production_companies, Length: 45466, dtype: object

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     11881
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
pd.read_csv('movies_metadata.csv',low_memory=False).isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40975
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   5
# poster_path                386
# production_companies     11881
# production_countries      6288
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages          3958
# status                      87
# tagline                  25054
# title                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df[df.title.isna()]
# Out:
#              belongs_to_collection                            budget  \
# 19729                          NaN                                 0
# 19730                          NaN  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29502  Mardock Scramble Collection                                 0
# 29503                          NaN  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35586                          NaN                                 0
# 35587                          NaN  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres          id  \
# 19729                              Action|Thriller|Drama       82663
# 19730  Carousel Productions|Vision View Entertainment...  1997-08-20
# 29502                          Animation|Science Fiction      122662
# 29503  Aniplex|GoHands|BROSTA TV|Mardock Scramble Pro...  2012-09-29
# 35586             TV Movie|Action|Horror|Science Fiction      249260
# 35587  Odyssey Media|Pulser Productions|Rogue State|T...  2014-01-01
#
#       original_language                                           overview  \
# 19729                en  British soldiers force a recently captured IRA...
# 19730             104.0                                           Released
# 29502                ja         Third film of the Mardock Scramble series.
# 29503              68.0                                           Released
# 35586                en  A group of skiers are terrorized during spring...
# 35587              82.0                                           Released
#
#                   popularity                          poster_path  \
# 19729                    NaN                                  NaN
# 19730                    NaN                         Midnight Man
# 29502                    NaN                                  NaN
# 29503                    NaN  Mardock Scramble: The Third Exhaust
# 35586                    NaN                                  NaN
# 35587  Beware Of Frost Bites                     Avalanche Sharks
#
#       production_companies production_countries release_date  revenue  \
# 19729                  NaN                  NaN          NaN      NaN
# 19730                  NaN                  NaN            1      NaN
# 29502                  NaN                  NaN          NaN      NaN
# 29503                  NaN                  NaN           12      NaN
# 35586                  NaN                  NaN          NaN      NaN
# 35587                  NaN                  NaN           22      NaN
#
#        runtime spoken_languages status tagline title  vote_average  vote_count
# 19729      NaN              NaN    NaN     NaN   NaN           NaN         NaN
# 19730      NaN              NaN    NaN     NaN   NaN           NaN         NaN
# 29502      NaN              NaN    NaN     NaN   NaN           NaN         NaN
# 29503      NaN              NaN    NaN     NaN   NaN           NaN         NaN
# 35586      NaN              NaN    NaN     NaN   NaN           NaN         NaN
# 35587      NaN              NaN    NaN     NaN   NaN           NaN         NaN

# %%
#menghapus semua data yang id dan titlenya nan
df.dropna(subset=['id','title'], inplace=True)

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40970
# budget                       0
# genres                    2442
# id                           0
# original_language           11
# overview                   954
# popularity                   0
# poster_path                383
# production_companies     11875
# production_countries      6282
# release_date                84
# revenue                      0
# runtime                    257
# spoken_languages          3952
# status                      81
# tagline                  25048
# title                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
df.id = df.id.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45460 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4490 non-null   object
#  1   budget                 45460 non-null  object
#  2   genres                 43018 non-null  object
#  3   id                     45460 non-null  int32
#  4   original_language      45449 non-null  object
#  5   overview               44506 non-null  object
#  6   popularity             45460 non-null  object
#  7   poster_path            45077 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45376 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45379 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45460 non-null  object
#  17  vote_average           45460 non-null  float64
#  18  vote_count             45460 non-null  float64
# dtypes: float64(4), int32(1), object(14)
# memory usage: 6.8+ MB

# %%
df.notna().sum(axis=1).value_counts().sort_values(ascending=False)
# Out:
# 18    16364
# 17    14908
# 16     5645
# 15     3072
# 19     2403
# 14     1882
# 13      878
# 12      228
# 11       63
# 10       12
# 9         5
# dtype: int64

# %%
df[df.notna().sum(axis=1)==10 ]
# Out:
#       belongs_to_collection budget       genres      id original_language  \
# 2140                    NaN      0          NaN   77314                fr
# 14890                   NaN      0          NaN  174748                no
# 18572                   NaN      0  Documentary  404471                fi
# 20711                   NaN      0          NaN   54356                fi
# 29309                   NaN      0          NaN  335141                fr
# 35652                   NaN      0          NaN  374698                nl
# 37209                   NaN      0          NaN  324408                de
# 37640                   NaN      0          NaN   54566                fi
# 40203                   NaN      0          NaN  410576                en
# 41399                   NaN      0          NaN  419289                es
# 43486                   NaN      0          NaN   74171                tr
# 44978                   NaN      0          NaN  398295                pt
#
#       overview popularity                       poster_path  \
# 2140       NaN     0.0375  /8prmlT6iOYl3zFsDDJl9oDMUGeD.jpg
# 14890      NaN        0.0                               NaN
# 18572      NaN        0.0                               NaN
# 20711      NaN    0.07607  /5IjAdqVpO5kvpqscU5qCkj2FssH.jpg
# 29309      NaN   0.001648                               NaN
# 35652      NaN    0.00129                               NaN
# 37209      NaN   0.145349                               NaN
# 37640      NaN   0.001189  /clWWlnuiV2n0fEjGPOnLgq4DKZF.jpg
# 40203      NaN   0.000253  /oUgQBEPLA8VAZtu5krty5zgKV1u.jpg
# 41399      NaN        0.0  /4qVpxyEtTZek9NZeasOIKdKOOve.jpg
# 43486      NaN   0.683873  /cu6evGag7D1IP5hCDHKnGjRoux4.jpg
# 44978      NaN   0.000331                               NaN
#
#       production_companies production_countries release_date  revenue  \
# 2140                   NaN                  NaN   1991-12-04      0.0
# 14890                  NaN                  NaN   1984-12-30      0.0
# 18572                  NaN                  NaN          NaN      0.0
# 20711                  NaN                  NaN   2001-09-26      0.0
# 29309                  NaN                  NaN   1998-01-01      0.0
# 35652                  NaN                  NaN   2001-10-24      0.0
# 37209                  NaN                  NaN   2007-12-12      0.0
# 37640                  NaN                  NaN   1966-08-26      0.0
# 40203                  NaN                  NaN          NaN      0.0
# 41399                  NaN                  NaN          NaN      0.0
# 43486                  NaN                  NaN   1976-09-01      0.0
# 44978                  NaN                  NaN          NaN      0.0
#
#        runtime spoken_languages    status tagline                       title  \
# 2140       NaN              NaN       NaN     NaN  The Cabinet of Dr. Ramirez
# 14890      NaN              NaN  Released     NaN               Lars i porten
# 18572      NaN              NaN  Released     NaN         Pölynimurikauppiaat
# 20711      NaN              NaN       NaN     NaN            Emmauksen tiellä
# 29309      NaN              NaN  Released     NaN           Bob le magnifique
# 35652      NaN              NaN  Released     NaN                      Vallen
# 37209      NaN              NaN  Released     NaN               Der Kronzeuge
# 37640      NaN              NaN       NaN     NaN                Millipilleri
# 40203      NaN              NaN  Released     NaN               Bad Dad Rehab
# 41399      NaN              NaN  Released     NaN     Allende en su laberinto
# 43486      NaN              NaN       NaN     NaN              Sahte Kabadayı
# 44978      0.0              NaN  Released     NaN                   Mundo Cão
#
#        vote_average  vote_count
# 2140            0.0         0.0
# 14890           0.0         0.0
# 18572           0.0         0.0
# 20711           7.0         2.0
# 29309           0.0         0.0
# 35652           0.0         0.0
# 37209           6.0         2.0
# 37640           0.0         0.0
# 40203           0.0         0.0
# 41399           0.0         0.0
# 43486           7.0         3.0
# 44978           0.0         0.0

# %%
#menghapus data yang Nannya ada 9
df.dropna(thresh=10,inplace=True)

# %%
df.notna().sum(axis=1).value_counts().sort_values(ascending=False)
# Out:
# 18    16364
# 17    14908
# 16     5645
# 15     3072
# 19     2403
# 14     1882
# 13      878
# 12      228
# 11       63
# 10       12
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45455 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4490 non-null   object
#  1   budget                 45455 non-null  object
#  2   genres                 43018 non-null  object
#  3   id                     45455 non-null  int32
#  4   original_language      45444 non-null  object
#  5   overview               44506 non-null  object
#  6   popularity             45455 non-null  object
#  7   poster_path            45077 non-null  object
#  8   production_companies   33585 non-null  object
#  9   production_countries   39178 non-null  object
#  10  release_date           45376 non-null  object
#  11  revenue                45455 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       41508 non-null  object
#  14  status                 45374 non-null  object
#  15  tagline                20412 non-null  object
#  16  title                  45455 non-null  object
#  17  vote_average           45455 non-null  float64
#  18  vote_count             45455 non-null  float64
# dtypes: float64(4), int32(1), object(14)
# memory usage: 6.8+ MB

# %%
df.isna().sum()
# Out:
# belongs_to_collection    40965
# budget                       0
# genres                    2437
# id                           0
# original_language           11
# overview                   949
# popularity                   0
# poster_path                378
# production_companies     11870
# production_countries      6277
# release_date                79
# revenue                      0
# runtime                    252
# spoken_languages          3947
# status                      81
# tagline                  25043
# title                        0
# vote_average                 0
# vote_count                   0
# dtype: int64

# %%
df.status.value_counts()
# Out:
# Released           45009
# Rumored              230
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %%
df.loc[df.status=='Released']
# Out:
#                 belongs_to_collection    budget                    genres  \
# 0                Toy Story Collection  30000000   Animation|Comedy|Family
# 1                                 NaN  65000000  Adventure|Fantasy|Family
# 2           Grumpy Old Men Collection         0            Romance|Comedy
# 3                                 NaN  16000000      Comedy|Drama|Romance
# 4      Father of the Bride Collection         0                    Comedy
# ...                               ...       ...                       ...
# 45461                             NaN         0              Drama|Family
# 45462                             NaN         0                     Drama
# 45463                             NaN         0     Action|Drama|Thriller
# 45464                             NaN         0                       NaN
# 45465                             NaN         0                       NaN
#
#            id original_language  \
# 0         862                en
# 1        8844                en
# 2       15602                en
# 3       31357                en
# 4       11862                en
# ...       ...               ...
# 45461  439050                fa
# 45462  111109                tl
# 45463   67758                en
# 45464  227506                en
# 45465  461257                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries release_date      revenue  runtime  \
# 0      United States of America   1995-10-30  373554033.0     81.0
# 1      United States of America   1995-12-15  262797249.0    104.0
# 2      United States of America   1995-12-22          0.0    101.0
# 3      United States of America   1995-12-22   81452156.0    127.0
# 4      United States of America   1995-02-10   76578911.0    106.0
# ...                         ...          ...          ...      ...
# 45461                      Iran          NaN          0.0     90.0
# 45462               Philippines   2011-11-17          0.0    360.0
# 45463  United States of America   2003-08-01          0.0     90.0
# 45464                    Russia   1917-10-21          0.0     87.0
# 45465            United Kingdom   2017-06-09          0.0     75.0
#
#        spoken_languages    status  \
# 0               English  Released
# 1      English|Français  Released
# 2               English  Released
# 3               English  Released
# 4               English  Released
# ...                 ...       ...
# 45461             فارسی  Released
# 45462               NaN  Released
# 45463           English  Released
# 45464               NaN  Released
# 45465           English  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  vote_average  vote_count
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
# [45009 rows x 19 columns]

# %%
df = df.loc[df.status=='Released'].copy()

# %%
df.status.value_counts()
# Out:
# Released    45009
# Name: status, dtype: int64

# %%
df.drop(columns=['status'],inplace=True)

# %%
col = ['id', 'title','tagline','release_date','genres','belongs_to_collection','original_language',
        'budget','revenue','production_companies','production_countries','vote_count',
        'vote_average','popularity','runtime','overview','spoken_languages','poster_path']

# %%
df = df.loc[:,col]

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 45461         Rising and falling between a man and woman          NaN
# 45462                                                NaN   2011-11-17
# 45463                             A deadly game of wits.   2003-08-01
# 45464                                                NaN   1917-10-21
# 45465                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 45461              Drama|Family                             NaN
# 45462                     Drama                             NaN
# 45463     Action|Drama|Thriller                             NaN
# 45464                       NaN                             NaN
# 45465                       NaN                             NaN
#
#       original_language    budget      revenue  \
# 0                    en  30000000  373554033.0
# 1                    en  65000000  262797249.0
# 2                    en         0          0.0
# 3                    en  16000000   81452156.0
# 4                    en         0   76578911.0
# ...                 ...       ...          ...
# 45461                fa         0          0.0
# 45462                tl         0          0.0
# 45463                en         0          0.0
# 45464                en         0          0.0
# 45465                en         0          0.0
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries  vote_count  vote_average popularity  runtime  \
# 0      United States of America      5415.0           7.7  21.946943     81.0
# 1      United States of America      2413.0           6.9  17.015539    104.0
# 2      United States of America        92.0           6.5    11.7129    101.0
# 3      United States of America        34.0           6.1   3.859495    127.0
# 4      United States of America       173.0           5.7   8.387519    106.0
# ...                         ...         ...           ...        ...      ...
# 45461                      Iran         1.0           4.0   0.072051     90.0
# 45462               Philippines         3.0           9.0   0.178241    360.0
# 45463  United States of America         6.0           3.8   0.903007     90.0
# 45464                    Russia         0.0           0.0   0.003503     87.0
# 45465            United Kingdom         0.0           0.0   0.163015     75.0
#
#                                                 overview  spoken_languages  \
# 0      Led by Woody, Andy's toys live happily in his ...           English
# 1      When siblings Judy and Peter discover an encha...  English|Français
# 2      A family wedding reignites the ancient feud be...           English
# 3      Cheated on, mistreated and stepped on, the wom...           English
# 4      Just when George Banks has recovered from his ...           English
# ...                                                  ...               ...
# 45461        Rising and falling between a man and woman.             فارسی
# 45462  An artist struggles to finish his work while a...               NaN
# 45463  When one of her hits goes wrong, a professiona...           English
# 45464  In a small town live two brothers, one a minis...               NaN
# 45465  50 years after decriminalisation of homosexual...           English
#
#                             poster_path
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [45009 rows x 18 columns]

# %%
#ganti nama column
df= df.rename(columns={'budget':'budget_musd', 'revenue':'revenue_musd'})

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 45461  439050                       Subdue
# 45462  111109          Century of Birthing
# 45463   67758                     Betrayal
# 45464  227506             Satan Triumphant
# 45465  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                  ...          ...
# 45461         Rising and falling between a man and woman          NaN
# 45462                                                NaN   2011-11-17
# 45463                             A deadly game of wits.   2003-08-01
# 45464                                                NaN   1917-10-21
# 45465                                                NaN   2017-06-09
#
#                          genres           belongs_to_collection  \
# 0       Animation|Comedy|Family            Toy Story Collection
# 1      Adventure|Fantasy|Family                             NaN
# 2                Romance|Comedy       Grumpy Old Men Collection
# 3          Comedy|Drama|Romance                             NaN
# 4                        Comedy  Father of the Bride Collection
# ...                         ...                             ...
# 45461              Drama|Family                             NaN
# 45462                     Drama                             NaN
# 45463     Action|Drama|Thriller                             NaN
# 45464                       NaN                             NaN
# 45465                       NaN                             NaN
#
#       original_language budget_musd  revenue_musd  \
# 0                    en    30000000   373554033.0
# 1                    en    65000000   262797249.0
# 2                    en           0           0.0
# 3                    en    16000000    81452156.0
# 4                    en           0    76578911.0
# ...                 ...         ...           ...
# 45461                fa           0           0.0
# 45462                tl           0           0.0
# 45463                en           0           0.0
# 45464                en           0           0.0
# 45465                en           0           0.0
#
#                                     production_companies  \
# 0                                Pixar Animation Studios
# 1      TriStar Pictures|Teitler Film|Interscope Commu...
# 2                            Warner Bros.|Lancaster Gate
# 3                 Twentieth Century Fox Film Corporation
# 4              Sandollar Productions|Touchstone Pictures
# ...                                                  ...
# 45461                                                NaN
# 45462                                        Sine Olivia
# 45463                            American World Pictures
# 45464                                          Yermoliev
# 45465                                                NaN
#
#            production_countries  vote_count  vote_average popularity  runtime  \
# 0      United States of America      5415.0           7.7  21.946943     81.0
# 1      United States of America      2413.0           6.9  17.015539    104.0
# 2      United States of America        92.0           6.5    11.7129    101.0
# 3      United States of America        34.0           6.1   3.859495    127.0
# 4      United States of America       173.0           5.7   8.387519    106.0
# ...                         ...         ...           ...        ...      ...
# 45461                      Iran         1.0           4.0   0.072051     90.0
# 45462               Philippines         3.0           9.0   0.178241    360.0
# 45463  United States of America         6.0           3.8   0.903007     90.0
# 45464                    Russia         0.0           0.0   0.003503     87.0
# 45465            United Kingdom         0.0           0.0   0.163015     75.0
#
#                                                 overview  spoken_languages  \
# 0      Led by Woody, Andy's toys live happily in his ...           English
# 1      When siblings Judy and Peter discover an encha...  English|Français
# 2      A family wedding reignites the ancient feud be...           English
# 3      Cheated on, mistreated and stepped on, the wom...           English
# 4      Just when George Banks has recovered from his ...           English
# ...                                                  ...               ...
# 45461        Rising and falling between a man and woman.             فارسی
# 45462  An artist struggles to finish his work while a...               NaN
# 45463  When one of her hits goes wrong, a professiona...           English
# 45464  In a small town live two brothers, one a minis...               NaN
# 45465  50 years after decriminalisation of homosexual...           English
#
#                             poster_path
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45461  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45462  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45463  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45464  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45465  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
# [45009 rows x 18 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45009 entries, 0 to 45008
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     45009 non-null  int32
#  1   title                  45009 non-null  object
#  2   tagline                20300 non-null  object
#  3   release_date           44936 non-null  object
#  4   genres                 42630 non-null  object
#  5   belongs_to_collection  4466 non-null   object
#  6   original_language      44999 non-null  object
#  7   budget_musd            45009 non-null  object
#  8   revenue_musd           45009 non-null  float64
#  9   production_companies   33379 non-null  object
#  10  production_countries   38865 non-null  object
#  11  vote_count             45009 non-null  float64
#  12  vote_average           45009 non-null  float64
#  13  popularity             45009 non-null  object
#  14  runtime                44763 non-null  float64
#  15  overview               44094 non-null  object
#  16  spoken_languages       41137 non-null  object
#  17  poster_path            44641 non-null  object
# dtypes: float64(4), int32(1), object(13)
# memory usage: 6.0+ MB

# %%
df.poster_path[1]
# Out:
# '/vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg'

# %%
base_poster_url = 'http://image.tmdb.org/t/p/w185/'
df.poster_path = "<img src='" + base_poster_url + df.poster_path + "' style='height:100px;'>"

# %%
df.to_csv('movie_cleanthomas.csv',index=False)

# %%
pd.read_csv('movie_cleanthomas.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45009 entries, 0 to 45008
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     45009 non-null  int64
#  1   title                  45009 non-null  object
#  2   tagline                20300 non-null  object
#  3   release_date           44936 non-null  object
#  4   genres                 42630 non-null  object
#  5   belongs_to_collection  4466 non-null   object
#  6   original_language      44999 non-null  object
#  7   budget_musd            45009 non-null  int64
#  8   revenue_musd           45009 non-null  float64
#  9   production_companies   33379 non-null  object
#  10  production_countries   38865 non-null  object
#  11  vote_count             45009 non-null  float64
#  12  vote_average           45009 non-null  float64
#  13  popularity             45009 non-null  float64
#  14  runtime                44763 non-null  float64
#  15  overview               44094 non-null  object
#  16  spoken_languages       41137 non-null  object
#  17  poster_path            44641 non-null  object
# dtypes: float64(5), int64(2), object(11)
# memory usage: 6.2+ MB
